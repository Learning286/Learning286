# %%
def get_text_splits(text_file):
  """Function takes in the text data and returns the  
  splits so for further processing can be done."""
  with open(text_file,'r') as txt:
    data = txt.read()

  textSplit = RecursiveCharacterTextSplitter(chunk_size=150,
                                             chunk_overlap=15,
                                             length_function=len)
  doc_list = textSplit.split_text(data)
  return doc_list

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
from langchain.vectorstores import Weaviate

# %%
import weaviate

# %% [markdown]
# import weaviate
# from weaviate.embedded import EmbeddedOptions
#
# client = weaviate.Client(
#   embedded_options=EmbeddedOptions()
# )
#
# data_obj = {
#   "name": "Chardonnay",
#   "description": "Goes with fish"
# }
#
# client.data_object.create(data_obj, "Wine")

# %%
client = weaviate.Client(
  url="http://localhost:8080",
  additional_headers={
        "X-HuggingFace-Api-Key": "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"
    }
)

# %%
schema = {
    "classes": [
        {
            "class": "Paragraph",
            "description": "A written paragraph",
         "moduleConfig": {
        "text2vec-huggingface": {
          "model": "sentence-transformers/all-MiniLM-L6-v2",
          "options": {
            "waitForModel": True,
            "useGPU": False,
            "useCache": True
            }
          }
        },
            "properties": [
                {
                    "dataType": ["text"],
                    "description": "The review text of the restuarant",
                    "moduleConfig": {
                        "text2vec-huggingface": {
                          "skip": False,
                          "vectorizePropertyName": False
                        }
                      },
                    "name": "content",
                },
                {
                    "dataType": ["int"],
                    "description": "The rating of the restuarant",
                    "moduleConfig": {
                        "text2vec-huggingface": {
                          "skip": False,
                          "vectorizePropertyName": False
                        }
                      },
                    "name": "Rating",
                }
            ],
         "vectorizer":"text2vec-huggingface"
        },
    ]
}

# %%
client.schema.delete_all()

# %%
schema
# Out:
# {'classes': [{'class': 'Paragraph',
#    'description': 'A written paragraph',
#    'moduleConfig': {'text2vec-huggingface': {'model': 'sentence-transformers/all-MiniLM-L6-v2',
#      'options': {'waitForModel': True, 'useGPU': False, 'useCache': True}}},
#    'properties': [{'dataType': ['text'],
#      'description': 'The review text of the restuarant',
#      'moduleConfig': {'text2vec-huggingface': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'content'},
#     {'dataType': ['int'],
#      'description': 'The rating of the restuarant',
#      'moduleConfig': {'text2vec-huggingface': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'Rating'}],
#    'vectorizer': 'text2vec-huggingface'}]}

# %%
client.schema.create(schema)

# %%
import pandas as pd
df=pd.read_csv("C:/Users/himansku/Documents/Data Science/Data Files/Restaurant_Reviews.tsv",sep='\t')

# %%
review_text=[]
rating=[]

# %%
for i in df.Review:
    review_text.append(i)
for i in df.Liked:
    rating.append(i)

# %%
review_text=review_text[0:100]
rating=rating[0:100]

# %%
client.data_object.get(class_name="Paragraph")
# Out:
# {'deprecations': [], 'objects': []}

# %%
with client.batch as batch:
    batch.batch_size=5
    for c,r in review_text,rating:
        properties = {
            "content": c,
            "rating": r
        }
        #time.sleep(5)
        client.batch.add_data_object(properties, "Paragraph")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-b27674b57625> in <module>
#       1 with client.batch as batch:
#       2     batch.batch_size=5
# ----> 3     for c,r in review_text,rating:
#       4         properties = {
#       5             "content": c,
#
# ValueError: too many values to unpack (expected 2)

# %%
import time
# Configure a batch process
with client.batch as batch:
    batch.batch_size=5
    j=0
    for j in range(j,(j+100)):
        for i, d in enumerate(review_text[j:(j+100)]):
        
            properties = {
                "content": d,
            }
        j=j+100
        time.sleep(5)
        client.batch.add_data_object(properties, "Paragraph")
# Out:
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# ...

# %%
with client.batch as batch:
    batch.batch_size=5
    for i, d in enumerate(review_text[0:100]):
        properties = {
            "content": d,
        }
        #time.sleep(5)
        client.batch.add_data_object(properties, "Paragraph")

with client.batch as batch:
    batch.batch_size=5
    for i, d in enumerate(rating[0:100]):
        properties = {
            "Rating": d,
        }
        #time.sleep(5)
        client.batch.add_data_object(properties, "Paragraph")

# %%
# maximum number of objects returned is 100.
# by default get() method will return arbitrary number of obj
client.data_object.get(limit=20,
                           with_vector=False)['objects']
# Out:
# []

# %%
client.data_object.get(limit=20,class_name="Paragraph",
                           with_vector=True)['objects']
# Out:
# [{'class': 'Paragraph',
#   'creationTimeUnix': 1696576447592,
#   'id': '018dcb91-30c5-4904-bd88-7a2966f88a57',
#   'lastUpdateTimeUnix': 1696576447592,
#   'properties': {'content': 'Omelets are to die for!'},
#   'vector': [-0.04491394,
#    0.098397955,
#    0.08201688,
#    -0.02076547,
#    0.06595357,
#    0.047573734,
#    0.04322679,
#    -0.07175535,
#    0.11128494,
#    0.02011089,
#    0.0021608528,
#    -0.0118623655,
#    -0.011070645,
#    -0.058130816,
#    -0.02606778,
#    0.037531067,
#    -0.051693365,
#    0.05413205,
#    -0.07567248,
#    0.08392373,
#    0.051265284,
#    0.12700956,
#    0.06677708,
#    0.025386706,
#    -0.033502493,
#    0.079745404,
#    -0.04043043,
#    -0.06556974,
#    -0.0055705104,
#    -0.03247282,
#    0.0057826354,
#    -0.050117947,
#    -0.032434933,
#    0.09374782,
#    -0.0070046973,
#    -0.0034249194,
#    0.033732127,
#    -0.067848526,
#    -0.020620069,
#    -0.04217803,
#    0.020055054,
#    -0.051854704,
# ...

# %%
result = (
    client.query
    .get("Paragraph", ["content"])
    .with_near_text({"concepts": ["Food"]})
    .with_limit(4)
    .do()
)

# %%
import json
print(json.dumps(result, indent=4))
# Out:
# {
#     "data": {
#         "Get": {
#             "Paragraph": [
#                 {
#                     "content": "The food, amazing."
#                 },
#                 {
#                     "content": "Food arrived quickly!"
#                 },
#                 {
#                     "content": "All I have to say is the food was amazing!!!"
#                 },
#                 {
#                     "content": "Not much seafood and like 5 strings of pasta at the bottom."
#                 }
#             ]
#         }
#     }
# }

# %%
client.data_object.get(class_name="Paragraph",with_vector=False)
# Out:
# {'deprecations': [],
#  'objects': [{'class': 'Paragraph',
#    'creationTimeUnix': 1696576447592,
#    'id': '018dcb91-30c5-4904-bd88-7a2966f88a57',
#    'lastUpdateTimeUnix': 1696576447592,
#    'properties': {'content': 'Omelets are to die for!'},
#    'vectorWeights': None},
#   {'class': 'Paragraph',
#    'creationTimeUnix': 1696576448610,
#    'id': '060def87-75c6-450d-befb-f45dcd2b42c3',
#    'lastUpdateTimeUnix': 1696576448610,
#    'properties': {'rating': 1},
#    'vectorWeights': None},
#   {'class': 'Paragraph',
#    'creationTimeUnix': 1696576445578,
#    'id': '0846215a-e66c-49c8-afe5-548237cae8ba',
#    'lastUpdateTimeUnix': 1696576445578,
#    'properties': {'content': 'Highly recommended.'},
#    'vectorWeights': None},
#   {'class': 'Paragraph',
#    'creationTimeUnix': 1696576447592,
#    'id': '086cefa7-76c9-48fc-82d5-ca6fc23df2c9',
#    'lastUpdateTimeUnix': 1696576447592,
#    'properties': {'content': 'All I have to say is the food was amazing!!!'},
# ...

# %%
#Data object Before update
client.data_object.get(uuid='1fb2e7ee-96ce-4ea8-b15e-82d690b3d084',class_name="Paragraph",with_vector=False)
# Out:
# {'class': 'Paragraph',
#  'creationTimeUnix': 1696576448344,
#  'id': '1fb2e7ee-96ce-4ea8-b15e-82d690b3d084',
#  'lastUpdateTimeUnix': 1696576448344,
#  'properties': {'rating': 0},
#  'vectorWeights': None}

# %%
#Updating a data object
client.data_object.update(uuid='1fb2e7ee-96ce-4ea8-b15e-82d690b3d084',class_name="Paragraph",data_object={
        'rating': 1,
    })

# %%
#Data object After update
client.data_object.get(uuid='1fb2e7ee-96ce-4ea8-b15e-82d690b3d084',class_name="Paragraph",with_vector=False)
# Out:
# {'class': 'Paragraph',
#  'creationTimeUnix': 1696576448344,
#  'id': '1fb2e7ee-96ce-4ea8-b15e-82d690b3d084',
#  'lastUpdateTimeUnix': 1696576864112,
#  'properties': {'rating': 1},
#  'vectorWeights': None}

# %%
#Data object Before update
client.data_object.get(uuid='086cefa7-76c9-48fc-82d5-ca6fc23df2c9',class_name="Paragraph",with_vector=False)
# Out:
# {'class': 'Paragraph',
#  'creationTimeUnix': 1696576447592,
#  'id': '086cefa7-76c9-48fc-82d5-ca6fc23df2c9',
#  'lastUpdateTimeUnix': 1696577387554,
#  'properties': {'content': 'All I have to say is the food was amazing!!!',
#   'rating': 0},
#  'vectorWeights': None}

# %%
#Updating a data object
client.data_object.update(uuid='086cefa7-76c9-48fc-82d5-ca6fc23df2c9',class_name="Paragraph",data_object={
        'content': "This is test",
    })

# %%
#Data object Before update
client.data_object.get(uuid='086cefa7-76c9-48fc-82d5-ca6fc23df2c9',class_name="Paragraph",with_vector=False)
# Out:
# {'class': 'Paragraph',
#  'creationTimeUnix': 1696576447592,
#  'id': '086cefa7-76c9-48fc-82d5-ca6fc23df2c9',
#  'lastUpdateTimeUnix': 1696577408775,
#  'properties': {'content': 'This is test', 'rating': 0},
#  'vectorWeights': None}

# %%
128006fd-8021-4088-93e6-0788ee65c305

# %%
#Add Data to existing column
client.data_object.update(data_object="content",class_name="Paragraph",uuid="03affbbd-cca2-418a-836d-d74c7e4069d2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-39b0488b4a5d> in <module>
#       1 #Add Data to existing column
# ----> 2 client.data_object.update(data_object="content",class_name="Paragraph",uuid="03affbbd-cca2-418a-836d-d74c7e4069d2")
#
# ~\Anaconda3\lib\site-packages\weaviate\data\crud_data.py in update(self, data_object, class_name, uuid, vector, consistency_level, tenant)
#     249         if consistency_level is not None:
#     250             params["consistency_level"] = ConsistencyLevel(consistency_level).value
# --> 251         weaviate_obj, path = self._create_object_for_update(data_object, class_name, uuid, vector)
#     252         if tenant is not None:
#     253             weaviate_obj["tenant"] = tenant
#
# ~\Anaconda3\lib\site-packages\weaviate\data\crud_data.py in _create_object_for_update(self, data_object, class_name, uuid, vector)
# ...

# %%
vectorstore = Weaviate(client, 
                       "Paragraph", 
                       "content")

# %%
vectorstore.similarity_search("Food")
# Out:
# [Document(page_content='The food, amazing.', metadata={}),
#  Document(page_content='Food arrived quickly!', metadata={}),
#  Document(page_content='All I have to say is the food was amazing!!!', metadata={}),
#  Document(page_content='Not much seafood and like 5 strings of pasta at the bottom.', metadata={})]

# %%
def load_docs(class_name, doc_list):
    # Configure a batch process
    with client.batch as batch:
        batch.batch_size=5
        batch = 0
        for i, d in enumerate(doc_list):
            print(f"processing batch {batch}")
            properties = {
                "content": d,
            }
            time.sleep(5)
            
            batch = batch + 1
            
            client.batch.add_data_object(properties, class_name)

# %%
v1=[-0.014334968,
   0.06941687,
   0.023409458,
   0.03453882,
   -0.0058051543,
   0.07893006,
   0.04180729,
   -0.016081724,
   0.05847946,
   -0.014663749,
   0.06551135,
   0.015369123,
   -0.0011071664,
   -0.008767312,
   -0.012625998,
   0.0009274041,
   0.062062845,
   -0.085935906,
   -0.16049889,
   0.040166274,
   0.018371796,
   0.06349126,
   0.04346403,
   0.022455232,
   -0.04327594,
   0.074951254,
   -0.04278371,
   0.024199765,
   0.021222366,
   -0.034839686,
   -0.008328836,
   0.010706301,
   0.04574592,
   0.05574766,
   -0.019711042,
   0.053115234,
   0.00501304,
   0.006706649,
   0.017459545,
   -0.056966525,
   -0.022426099,
   -0.10843401,
   0.0010950372,
